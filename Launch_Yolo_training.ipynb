# %%
# !wandb disabled

# %%
training_name = "yolov7_custom_white_multivariety"
prm = { # parameters
    'device' : 0,
    'batch-size': 16,
    'epochs' : 100,
    'img': "640 640",
    'data': f'data/{training_name}.yaml',
    'cfg': f'cfg/training/{training_name}.yaml',
    'name': training_name,
    'hyp': f'data/hyp.scratch.{training_name}.yaml',
    'weights': 'cfg/training/yolov7.pt'
}

# !python train.py --device {prm['device']} --batch-size {prm['batch-size']} --epochs {prm['epochs']} --img {prm['img']} --data {prm['data']} --cfg {prm['cfg']} --name {prm['name']} --hyp {prm['hyp']} --weights {prm['weights']}
# Out:
# YOLOR 🚀 v0.1-124-g7f8e6cd torch 1.12.1+cu116 CUDA:0 (NVIDIA RTX A5000, 24256.3125MB)
#
# Namespace(weights='cfg/training/yolov7.pt', cfg='cfg/training/yolov7_custom_white_multivariety.yaml', data='data/yolov7_custom_white_multivariety.yaml', hyp='data/hyp.scratch.yolov7_custom_white_multivariety.yaml', epochs=100, batch_size=16, img_size=[640, 640], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='yolov7_custom_white_multivariety', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/yolov7_custom_white_multivariety5', total_batch_size=16)
# ...

# %%
training_name = "yolov7_custom_JBoulent_chardonnay"
prm = { # parameters
    'device' : 0,
    'batch-size': 16,
    'epochs' : 100,
    'img': "640 640",
    'data': f'data/{training_name}.yaml',
    'cfg': f'cfg/training/{training_name}.yaml',
    'name': training_name,
    'hyp': f'data/hyp.scratch.{training_name}.yaml',
    'weights': 'cfg/training/yolov7.pt'
}

# !python train.py --device {prm['device']} --batch-size {prm['batch-size']} --epochs {prm['epochs']} --img {prm['img']} --data {prm['data']} --cfg {prm['cfg']} --name {prm['name']} --hyp {prm['hyp']} --weights {prm['weights']}
# Out:
# YOLOR 🚀 v0.1-124-g7f8e6cd torch 1.12.1+cu116 CUDA:0 (NVIDIA RTX A5000, 24256.3125MB)
#
# Namespace(weights='cfg/training/yolov7.pt', cfg='cfg/training/yolov7_custom_JBoulent_chardonnay.yaml', data='data/yolov7_custom_JBoulent_chardonnay.yaml', hyp='data/hyp.scratch.yolov7_custom_JBoulent_chardonnay.yaml', epochs=100, batch_size=16, img_size=[640, 640], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='yolov7_custom_JBoulent_chardonnay', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/yolov7_custom_JBoulent_chardonnay', total_batch_size=16)
# ...

# %%
"""
Namespace(weights='cfg/training/yolov7.pt', cfg='cfg/training/yolov7_custom_JBoulent_chardonnay.yaml', data='data/yolov7_custom_JBoulent_chardonnay.yaml', hyp='data/hyp.scratch.yolov7_custom_JBoulent_chardonnay.yaml', epochs=100, batch_size=16, img_size=[640, 640], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='yolov7_custom_JBoulent_chardonnay', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/yolov7_custom_JBoulent_chardonnay', total_batch_size=16)
tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.3, cls_pw=1.0, obj=0.7, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.2, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, paste_in=0.0, loss_ota=1
config set opt = {'weights': 'cfg/training/yolov7.pt', 'cfg': 'cfg/training/yolov7_custom_JBoulent_chardonnay.yaml', 'data': 'data/yolov7_custom_JBoulent_chardonnay.yaml', 'hyp': {'lr0': 0.01, 'lrf': 0.1, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'warmup_bias_lr': 0.1, 'box': 0.05, 'cls': 0.3, 'cls_pw': 1.0, 'obj': 0.7, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.2, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0, 'paste_in': 0.0, 'loss_ota': 1}, 'epochs': 100, 'batch_size': 16, 'img_size': [640, 640], 'rect': False, 'resume': False, 'nosave': False, 'notest': False, 'noautoanchor': False, 'evolve': False, 'bucket': '', 'cache_images': False, 'image_weights': False, 'device': '0', 'multi_scale': False, 'single_cls': False, 'adam': False, 'sync_bn': False, 'local_rank': -1, 'workers': 8, 'project': 'runs/train', 'entity': None, 'name': 'yolov7_custom_JBoulent_chardonnay', 'exist_ok': False, 'quad': False, 'linear_lr': False, 'label_smoothing': 0.0, 'upload_dataset': False, 'bbox_interval': -1, 'save_period': -1, 'artifact_alias': 'latest', 'freeze': [0], 'v5_metric': False, 'world_size': 1, 'global_rank': -1, 'save_dir': 'runs/train/yolov7_custom_JBoulent_chardonnay', 'total_batch_size': 16} - None
config set data_dict = {'train': '/home/paperspace/GitHub/yolov7/annotated_datasets_for_yolo/FD_JBoulent/train', 'val': '/home/paperspace/GitHub/yolov7/annotated_datasets_for_yolo/FD_JBoulent/val', 'test': '/home/paperspace/GitHub/yolov7/annotated_datasets_for_yolo/FD_JBoulent/test', 'nc': 2, 'names': ['FD', 'NONFD']} - None

Training fermato dopo circa 112 minuti all'epoca
 Class      Images      Labels           P           R      mAP@.5
 all          90         767       0.139       0.221      0.0849      0.0289

     Epoch   gpu_mem       box       obj       cls     total    labels  img_size
     42/99     14.2G   0.04803   0.04353  0.007583   0.09914       213       640
"""

# %%
# ATTENZIONE: eseguire questa cella per riprendere un training interrotto
training_name = "yolov7_custom_JBoulent_chardonnay"
# !python train.py --resume runs/train/{training_name}/weights/last.pt
# Out:
# Resuming training from runs/train/yolov7_custom_JBoulent_chardonnay/weights/last.pt
# YOLOR 🚀 v0.1-127-gbdfc40a torch 1.12.1+cu116 CUDA:0 (NVIDIA RTX A5000, 24256.3125MB)
#
# ...

# %%
# ATTENZIONE: eseguire questa cella per riprendere un training interrotto
training_name = "yolov7_custom_white_multivariety"
# !python train.py --resume runs/train/{training_name}/weights/last.pt

# %%
training_name = "yolov7_custom_white_multivariety"
prm = { # parameters
    'img-size' : 832,
    'batch-size': 16,
    'data': f'data/{training_name}.yaml',
    'cfg': f'cfg/training/{training_name}.yaml',
    'name': training_name,
    'conf-thres': '=0.03',
    'iou-thres': '=0.1',
    'weights': f'runs/train/{training_name}/weights/best.pt'
}

# !python test.py --img-size {prm['img-size']} --batch-size {prm['batch-size']} --data {prm['data']} --weights {prm['weights']} #--conf-thres=0.03 --iou-thres=0.1

# %%
training_name = "yolov7_custom_white_multivariety"
prm = { # parameters
    'weights': f'runs/train/{training_name}/weights/best.pt',
    'source'   : f'annotated_datasets_for_yolo/Esca_FD_multivariety_white/val/images',
    'save-txt' : '--save-txt'
}

# DOES YOLOV7 PRODUCE A LABEL TXT FILE IF IT DOES NOT DETECT OBJECTS INSIDE AN IMAGE? LET'S FIND OUT.
# THE IMAGE "Gler_tesista_IMG_20200605_184803.JPG" DOES NOT CONTAIN ANY OCCURRENCE OF RELEVANT OBJECTS
# THE ANSWER IS: YOLOV7 DOES NOT PRODUCE A LABEL TXT FILE IF IT DOES NOT DETECT OBJECTS INSIDE THE IMAGE
# !python detect.py --weights {prm['weights']} --source {prm['source']} {prm['save-txt']}
